# %% [markdown]
# # Student Performance Indicator

# %% [markdown]
# #### life cycle of Machine Learning Project

# %% [markdown]
# * Understanding the Problem Statement
# * Data Collection
# * Data Checks to perform
# * Exploratory data Analysis
# * Data Pre Processing
# * Model Training
# * Evaluation of the model / choose  best model

# %% [markdown]
# ### 1) Problem Statement

# %% [markdown]
# * This project understands how the student's performance (test scores) is affected by the other  variables such as gender ,ethinicity, parental level of education , lunch and test preaparation

# %% [markdown]
# ### 2) Data Collection

# %% [markdown]
# * Data Source-https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?select=StudentsPerformance.csv
# * The data consists of 8 columns and 1000 rows

# %% [markdown]
# ### 2.1) Import Data and Required Packages

# %% [markdown]
# * Importing Pandas, Numpy, Matplotlib, Seaborn and Waring Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import  warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6224\3800983157.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### 2.2) import the CSV data as Pandas DataFrame

# %%
df = pd.read_csv('data/StudentsPerformance.csv')

# %% [markdown]
# ### show top 5 rows

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
### shape of data set

# %% [markdown]
# ### 2.3) Dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.columns.unique()
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# ### dataset information

# %% [markdown]
# * gender: male/femali
# * race/ethinicity: group(A,B,C,D,E)
# * parental level of education: (bachelor/college/master/associates degree/high school)
# * lunch: standard/free/reducced
# * test preparation course: complete or not complete before test
# * math score
# * reading score
# * writting score

# %% [markdown]
# ### 3. Data Checks to perform

# %% [markdown]
# * check Missing values
# * check duplicates
# * check datatype
# * check the number of unique values of each
# * check statics of data set
# * check various categories present in the different categorical column

# %% [markdown]
# ### 3.1) check Missing values

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# there is no missing values in the data set

# %% [markdown]
# ### 3.3) Checks Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicates

# %% [markdown]
# ### 3.4) Check data types

# %% [markdown]
# check null and dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ### 3.4) Checking the number of unique values of each columns

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# ###  3.5) Check statistics of data set

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Insight
# * form above description of numerical data. all means are very close to each other- between 66 and 68.05
# * all standard deviations are also close - betwwen 14.6 and 15.19
# * while there is a minimum score 0 math for writing minimum is much higher = 10 and for reading myet higher =17

# %% [markdown]
# #### 3.7) Exploring Data

# %%
print("categories in 'gender' variable:  ",end=" ")
print(df['gender'].unique())
# Out:
# categories in 'gender' variable:   ['female' 'male']

# %%
print("categories in 'race/ethnicity' variable: ",end=" ")
print(df['race/ethnicity'].unique())
# Out:
# categories in 'race/ethnicity' variable:  ['group B' 'group C' 'group A' 'group D' 'group E']

# %%
print("Categories in 'parental level of education' variable:  ",end=" ")
print(df['parental level of education'].unique())
# Out:
# Categories in 'parental level of education' variable:   ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']

# %%
print("Categories in 'lunch' variable: ",end=" ")
print(df['lunch'].unique())
# Out:
# Categories in 'lunch' variable:  ['standard' 'free/reduced']

# %%
print("categoris in 'test preparation course' variable: ", end=" ")
print(df['test preparation course'].unique())
# Out:
# categoris in 'test preparation course' variable:  ['none' 'completed']

# %% [markdown]
# ### 3.7) Define Numerical and Categorical columns

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O'] ## not 'O' onject type
print(f'we have {len(numeric_features)} numerical features : {numeric_features} ')
# Out:
# we have 3 numerical features : ['math score', 'reading score', 'writing score']

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype =='O']
print(f'we have {len(categorical_features)} categorcal features :{categorical_features}')
# Out:
# we have 5 categorcal features :['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %% [markdown]
# ### 3.8) Adding columns for 'Total Score' and "Average"

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
df['total score']= df['math score'] + df['reading score'] + df['writing score']
df['average'] =  df['total score'] / 3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# * number of student with full marks in Maths:-

# %%
  math_full = df[df['math score']==100 ].count()
  print(f"number of student with full marks in maths : {math_full}")
# Out:
# number of student with full marks in maths : gender                         7
# race/ethnicity                 7
# parental level of education    7
# lunch                          7
# test preparation course        7
# math score                     7
# reading score                  7
# writing score                  7
# total score                    7
# average                        7
# dtype: int64

# %%
math_full = df[df['math score']==100 ]['average'].count()
print(f"number of student with full marks in maths : {math_full}")
# Out:
# number of student with full marks in maths : 7

# %%
math_full = df[df['writing score']==100 ]['average'].count()
print(f"number of student with full marks in writing : {math_full}")
# Out:
# number of student with full marks in writing : 14

# %%
math_full = df[df['reading score']==100 ]['average'].count()
print(f"number of student with full marks in reading : {math_full}")
# Out:
# number of student with full marks in reading : 17

# %% [markdown]
# * number of student with less than 20 marks in Maths:-

# %%
math_less_20 = df[df['math score'] <20  ]['average'].count()
print(f"number of student with less than 20 marks in maths : {math_less_20}")
# Out:
# number of student with less than 20 marks in maths : 4

# %%
reading_less_20 = df[df['reading score'] <20  ]['average'].count()
print(f"number of student with less than 20 marks in reading : {reading_less_20}")
# Out:
# number of student with less than 20 marks in reading : 1

# %%
writing_less_20 = df[df['writing score'] <20  ]['average'].count()
print(f"number of student with less than 20 marks in writing  : {writing_less_20}")
# Out:
# number of student with less than 20 marks in writing  : 3

# %% [markdown]
# ### Insight

# %% [markdown]
# * from above values we get students have performed the worst in Maths
# * Best performance is in reading section

# %% [markdown]
# ### 4. Exploring Data(Visualization)

# %% [markdown]
# 4.1 Visualize average score distribution to make some conclusion

# %% [markdown]
# * Histogram
# * Kernel Distribution Function (KDE)

# %% [markdown]
# ### 4.1.1 Histogram and KDE

# %% [markdown]
# ### Male vs Feamale performance

# %%
fig, axs = plt.subplots(1,2,figsize=(15,7)) ##subjplot 1 row 2 columns box  figsize=##(width, height)
#plt.subplots() is a function that returns a tuple containing a figure and axes object(s).
# Thus when using fig, ax = plt.subplots() you unpack this tuple into the variables fig and ax. 
# Having fig is useful if you want to change figure-level attributes or save the figure as an image 
# file later (e.g. with fig.savefig('yourfilename.png')). You certainly don't have to use the returned 
# figure object but many people do use it later so it's common to see. Also, all axes objects 
# (the objects that have plotting methods), have a parent figure object 
plt.subplot(121)  #You can place plots within a m x n grid, where m contains the number of rows and 
# contains the number of columns in your figure. p determines where you want to place your plot withi
# n the grid. The number p increases from 1 up to m x n, and the plots are placed from left to right, and top to bottom.
sns.histplot(data=df,x='average', bins=30, kde=True,color='g') #datapandas.DataFrame, numpy.ndarray, mapping, or sequence
# Input data structure x, yvectors or keys in data Variables that specify positions on the x and y axes binsstr, number, vector, or a pair of such values
# Generic bin parameter that can be the name of a reference rule, the number of bins, or the breaks of the bins. Passed to numpy.histogram_bin_edges().
# kdebool
#  If True, compute a kernel density estimate to smooth the distribution and show on the plot as (one or more) line(s). Only relevant with univariate data.
# huevector or key in data
# Semantic variable that is mapped to determine the color of plot elements.
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True, hue='gender')
plt.show()

# %%
fig, axs = plt.subplots(1,2, figsize=(15,7))  ##figsize=(width, height)

# %%
plt.subplot(121)
# Out:
# <Axes: >

# %%
sns.histplot(data=df, x= 'total score', bins=30, kde=True, color='g')
# Out:
# <Axes: xlabel='total score', ylabel='Count'>

# %%
sns.histplot(data=df,x='total score', bins=30, kde=True,hue='gender', color='g')
# Out:
# <Axes: xlabel='total score', ylabel='Count'>

# %%
plt.show()

# %% [markdown]
# ### insight
# Female students tend to perform well than male students

# %% [markdown]
# ### Effect of lunch on the performance

# %%
plt.subplots(1,3, figsize=(25,6)) #figsize=(width, height)
plt.subplot(141)
sns.histplot(data=df, x='average', kde=True, hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'], x ='average', kde=True, hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'], x='average', kde=True, hue='lunch')
plt.show()

# %% [markdown]
# ### insight

# %% [markdown]
# * standard lunch helps perform well in exams
# * standard lunch helps perform well in exams be it a male or a female

# %% [markdown]
# ### Effect of parent's education on the performance

# %%
plt.subplots(1,3, figsize=(25,6)) #figsize=(width, height)
plt.subplot(141)
ax = sns.histplot(data=df, x='average',kde=True, hue='parental level of education' )

# %%
plt.subplot(142)
ax = sns.histplot(data=df[df.gender=='male'], x='average', kde=False, hue='parental level of education') ## kde plot line chart over histogram

# %%
plt.subplot(142)
ax = sns.histplot(data=df[df.gender=='male'], x='average', kde=True, hue='parental level of education')  ## kde plot line chart over histogram

# %%
plt.subplot
ax = sns.histplot(data=df[df.gender=='female'],x='average',kde=True, hue='parental level of education')

# %%
plt.subplots(1,3, figsize=(35,10)) ##(width, height)
plt.subplot(141)
ax = sns.histplot(data=df, x='average',kde=True, hue='parental level of education' )
plt.subplot(142)
ax = sns.histplot(data=df[df.gender=='male'], x='average', kde=True, hue='parental level of education')
plt.subplot(143)
ax = sns.histplot(data=df[df.gender=='female'],x='average',kde=True, hue='parental level of education')
plt.show()

# %% [markdown]
# ### Insight

# %% [markdown]
# * in general parent's education don't help student perform well in exam
# * 2nd plot shows that parent's whose education is of associate's degree or master degree their male child tend to perform well in exam
# * 3rd plot we can see there is no effect of parent's education on female students

# %% [markdown]
# ### Effect of group on the performance

# %%
plt.subplots(1,3,figsize=(25,6)) ##(width, height)
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race/ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race/ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race/ethnicity')
# plt.show()

# %% [markdown]
# ### insight
# * Student of group A and group B tends to perform poorly in exam irrespective of wheather they are male or feamale

# %% [markdown]
# ### Maximum score of students in all three subject

# %%
plt.figure(figsize=(18,8)) ##(width, height)
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('READING SCORES')
sns.violinplot(y='writing score',data=df,color='blue',linewidth=3)
plt.show()

# %%
plt.figure(figsize=(10,4)) ##(width, height)
plt.subplot(1, 4, 1)
plt.title('READING SCORES')
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.boxplot(y='reading score',data=df,color='green',linewidth=3)
# plt.show()
plt.subplot(1, 4, 3)
sns.boxplot(y='writing score', data=df, color='yellow',linewidth=3)
# Out:
# <Axes: ylabel='writing score'>

# %% [markdown]
# ### Insight
# * From the above three plots its clearly visible that most of the students score in between 60 to 80 in math whereas in reading and writing most of them score from 50-80

# %% [markdown]
# ### Multivariate analysis using pieplot

# %%
plt.rcParams['figure.figsize']= (20,10) ##(width, height)

plt.subplot(1,5,1)
size = df['gender'].value_counts()
labels = 'Female','Male'
color=['red','green']

plt.pie(size, colors=color, labels=labels, autopct = '.%2f%%')
plt.title('gender', fontsize=20)
plt.axis('off')

plt.subplot(1, 5, 2)
size = df['race/ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 4)
size = df['test preparation course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 5)
size = df['parental level of education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')

plt.pie(size, colors = color,labels = labels,autopct = '%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# ### Insight
# * Number of Male and Female students is almost equal
# * Number students are greatest in grpup c
# * Number of students who have standard lunch are greater
# * Number of students who have not enrolled in any test preparation course is greater
# * Number of students whose parental education is "Some College" is greater followed closely by "Associate's Degree"

# %% [markdown]
# ### Feature Wise Visualization

# %% [markdown]
# ### Gender Column

# %% [markdown]
# * How is distribution of Gender ?
# * Is gender has any impact on student's performance?

# %% [markdown]
# ### Univariate Analysis (How is distribution of Gender ?)

# %%
f , ax = plt.subplots(1,2, figsize=(15,4))
sns.countplot(x=df['gender'],data=df,palette = 'bright', ax=ax[0],saturation=0.95)   ## palettepalette name, list, or dict
# Colors to use for the different levels of the hue variable. Should be something that can be interpreted by color_palette(), or 
# a dictionary mapping hue levels to matplotlib colors.
# saturation float
# Proportion of the original saturation to draw fill colors in. Large patches often look better with desaturated colors
# , but set this to 1 if you want the colors to perfectly match the input values.
# ax  matplotlib Axes
# Axes object to draw the plot onto, otherwise uses the current Axes.
for container in ax[0].containers:
    ax[0].bar_label(container, color='black',size=20)  ##Axes.bar_label matplotlib https://matplotlib.org › stable › api › _as_gen › matpl...
# container BarContainer. Container with all the bars and optionally errorbars ... float, default: 0. Distance of label from the end of the bar, in points ...

plt.pie(x=df['gender'].value_counts(), labels=['Female','Male'],explode=[0,0.1],autopct='%2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x28f43a0f350>,
# ...
#  [Text(-0.06217041096298424, 1.0982417038160106, 'Female'),
#   Text(0.06782226650507357, -1.1980818587083752, 'Male')],
#  [Text(-0.033911133252536856, 0.5990409293541875, '51.800001%'),
#   Text(0.03956298879462625, -0.698881084246552, '48.199999%')])

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ### Insight
# * gender has balanced data with female student are 518(52%) and male students are 482 (48%)

# %% [markdown]
# ### Bivariate Analysis( Is gender has any impact on student's performance ?)

# %%
gender_group_avr = df.groupby('gender')['average'].mean() ## first grouped by gender then  
# calculate the mean of 'average' for each group
gender_group_avr = df.groupby('gender').mean(numeric_only=True) 

gender_group_math = df.groupby('gender')['math score'].mean() #irst grouped by gender then  
# calculate the mean of 'math score' for each group

# %%
gender_group_avr,gender_group_math
# Out:
# (gender
#  female    69.569498
#  male      65.837483
#  Name: average, dtype: float64,
#  gender
#  female    63.633205
#  male      68.728216
#  Name: math score, dtype: float64)

# %%
x=['average','math score']
for  i in range(len(x)):
    gender_group = df.groupby('gender')[x[i]].mean()
    print(gender_group)
# Out:
# gender
# female    69.569498
# male      65.837483
# Name: average, dtype: float64
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
plt. figure(figsize=(10,4))

X = ['Total Average','Math Average']

female_scores = [gender_group_avr[0],gender_group_math[0]]
male_scores = [gender_group_avr[1], gender_group_math[1]]
# female_scores,male_scores
X_axis = np.arange(len(X))
plt.bar(X_axis-0.2, male_scores,0.4, label='Male')
plt.bar(X_axis+0.2, female_scores, 0.4, label='Female')

plt.xticks(X_axis,X) ##  X axis labels
plt.ylabel('Marks') # Label for y axis
plt.title("Total average v/s Math average marks of both the genders", fontweight="bold") # Title for the plot
plt.legend()
plt.show()

# %% [markdown]
# ### Insight
# * On an average females have a better overall score than men
# * whereas males have scored higher in Maths

# %% [markdown]
# ### Race/Ethencity Column
# * How is Group wise distribution ?
# * Is Race/Ethencity has any impact on student's performance

# %% [markdown]
# ### UNIVARIATE ANALYSIS ( How is Group wise distribution ?)|

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
f , ax=plt.subplots(1,2,figsize=(10,3))
sns.countplot(x=df['race/ethnicity'],data=df, palette='bright',ax=ax[0], saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
plt.pie(x=df['race/ethnicity'].value_counts(), labels=df['race/ethnicity'].value_counts(),autopct='%2f%%')
plt.show()

# %% [markdown]
# ### Insight
# * Most of the student belonging from group C/ group D
# * lowest number of students belong to group A

# %% [markdown]
# ### Bivariate Analysis (Is Race/Ethnicity has any impact on student's performance ?)

# %%
Group_data2=df.groupby('race/ethnicity')
f,ax = plt.subplots(1,3,figsize=(15,6)) # Create a 1x3 figure with 1 row and 3 columns
sns.barplot(x=Group_data2['math score'].mean().index, y=Group_data2['math score'].mean().values, ax=ax[0])# Add
ax[0].set_title('math score',color='green',size=20)

for container in ax[0].containers:
    ax[0].bar_label(container, color='black', size=15)

sns.barplot(x=Group_data2['reading score'].mean().index, y=Group_data2['reading score'].mean().values,ax=ax[1])
ax[1].set_title('Reading score', color='red',size=20)

for conatainer in ax[1].containers:
    ax[1].set_title('Reading score',color="blue", size=15)

sns.barplot(x=Group_data2['writing score'].mean().index,y=Group_data2['writing score'].mean().values,ax=ax[2])
ax[2].set_title('Writing score',color= 'purple' ,size=20)

for container in ax[2].containers:
    ax[2].bar_label(container,color='black',size=15)

# %% [markdown]
# ### Insight
# * Group E students have scored the highest marks
# * Group A Students have scored the lowest marks
# * Students from a lower Socioeconomic status have a lower avg in all course subjects

# %% [markdown]
# ### Parental level of Education column
# * what is educational background of student's parent?
# * Is parental education has any impact on student's performance?

# %% [markdown]
# ### Univariate Analysis (What is educational background of student's parent ?)

# %%
plt.rcParams['figure.figsize'] = (15,9)
plt.style.use('fivethirtyeight') ##style sheet
sns.countplot(df['parental level of education'],palette='Blues')
plt.title('Comparison of Parental Education',fontweight=30, fontsize=20)
plt.xlabel('count')
plt.ylabel('Degree')
plt.show()

# %% [markdown]
# ### Insights
# * Largest number of parents are from some college

# %% [markdown]
# ### Bivariate Analysis (Is parental education has any impact on student's performance ?)

# %%
df.groupby('parental level of education').agg('mean',numeric_only=True).plot(kind='barh',figsize= (10,10)) #first grouped by parental educaiton then  
# calculate the mean of 'each numeric column' for each group then aggregrate
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ### Insights
# * The score of student whose parents possess master and bachelor level education are higher than others

# %% [markdown]
# ### Lunch Collumns
#
# * which type of lunch is most common amoung students ?
# * what is the  effect of lunch  type on test resulst ?

# %% [markdown]
# ### Univariate Analysis (Which type of lunch is most  common among student?)

# %%
plt.rcParams['figure.figsize'] = (15, 9)
# plt.style.use('seaborn-talk')
sns.countplot(df['lunch'], palette = 'PuBu')
plt.title('Comparison of different types of lunch', fontweight = 30, fontsize = 20)
plt.ylabel('types of lunch')
plt.xlabel('count')
plt.show()

# %% [markdown]
# ### Insigt
# * students being served Standard lunch was more than free lunch

# %% [markdown]
# ### BIVARIATE ANALYSIS ( Is lunch type intake has any impact on student's performance ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='test preparation course',saturation=0.95,ax=ax[0])
ax[0].set_title('Students vs test preparation course ',color='black',size=25)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='lunch',saturation=0.95,ax=ax[1])
for container in ax[1].containers:
    ax[1].bar_label(container,color='black',size=20)

# %% [markdown]
# ### Insights
# * Students who get Standard Lunch tend to perform better than students who got free/reduced lunch

# %% [markdown]
# #### BIVARIATE ANALYSIS ( Is lunch type intake has any impact on student's performance ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='test preparation course',saturation=0.95,ax=ax[0])
ax[0].set_title('Students vs test preparation course ',color='black',size=25)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
sns.countplot(x=df['parental level of education'],data=df,palette = 'bright',hue='lunch',saturation=0.95,ax=ax[1])
for container in ax[1].containers:
    ax[1].bar_label(container,color='black',size=20)

# %% [markdown]
# * ### INsight
# * tudents who get Standard Lunch tend to perform better than students who got free/reduced lunch

# %% [markdown]
# ### TEST PREPARATION COURSE COLUMN
# * Which type of lunch is most common amoung students ?
# * Is Test prepration course has any impact on student's performance ?

# %% [markdown]
# ### BIVARIATE ANALYSIS ( Is Test prepration course has any impact on student's performance ? )

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot (x=df['lunch'], y=df['math score'], hue=df['test preparation course'])
plt.subplot(2,2,2)
sns.barplot (x=df['lunch'], y=df['reading score'], hue=df['test preparation course'])
plt.subplot(2,2,3)
sns.barplot (x=df['lunch'], y=df['writing score'], hue=df['test preparation course'])
# Out:
# <Axes: xlabel='lunch', ylabel='writing score'>

# %% [markdown]
# ### Insights
# * Students who have completed the Test Prepration Course have scores higher in all three categories than those who haven't taken the course

# %% [markdown]
# ### CHECKING OUTLIERS

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['math score'],color='skyblue')
plt.subplot(142)
sns.boxplot(df['reading score'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['writing score'],color='yellow')
plt.subplot(144)
sns.boxplot(df['average'],color='lightgreen')
plt.show()

# %% [markdown]
# ### MUTIVARIATE ANALYSIS USING PAIRPLOT

# %%
sns.pairplot(df,hue = 'gender')
plt.show()

# %% [markdown]
# ### Insights
# * From the above plot it is clear that all the scores increase linearly with each other.

# %% [markdown]
# ### Conclusions
# * Student's Performance is related with lunch, race, parental level education
# * Females lead in pass percentage and also are top-scorers
# * Student's Performance is not much related with test preparation course
# * Finishing preparation course is benefitial.
